# %%
import pandas as pd
import numpy as np
import json
from nltk.corpus import stopwords

# %%
import textract

# %%
pdf = textract.process(filename2)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-74-754357c15023> in <module>()
# ----> 1 pdf = textract.process(filename2)
#
# /Users/apoorvc/anaconda2/lib/python2.7/site-packages/textract/parsers/__init__.pyc in process(filename, encoding, **kwargs)
#      56     filetype_module = importlib.import_module(rel_module, 'textract.parsers')
#      57     parser = filetype_module.Parser()
# ---> 58     return parser.process(filename, encoding, **kwargs)
#
# /Users/apoorvc/anaconda2/lib/python2.7/site-packages/textract/parsers/utils.pyc in process(self, filename, encoding, **kwargs)
#      43         # output encoding
#      44         # http://nedbatchelder.com/text/unipain/unipain.html#35
# ---> 45         byte_string = self.extract(filename, **kwargs)
#      46         unicode_string = self.decode(byte_string)
# ...

# %%
from tika import parser

# %%
tika_pdf = parser.from_file(filename2)

# %%
tika_pdf
# Out:
# {'content': u"\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n3M\u2122 Super 77\u2122 Adhesive, Bulk    05/11/15\n\n__________________________________________________________________________________________\n  Page  1  of    12\n\nSafety Data Sheet\n\nCopyright,2015,3M Company.\nAll rights reserved. Copying and/or downloading of this information for the purpose of properly utilizing 3M products is \nallowed provided that: (1) the information is copied in full with no changes unless prior written agreement is obtained from \n3M, and (2) neither the copy nor the original is resold or otherwise distributed with the intention of earning a profit thereon.\n\nDocument Group: 09-2089-2 Version Number: 5.00\nIssue Date: 05/11/15 Supercedes Date: 07/12/13\n\nSECTION 1: Identification\n\n1.1. Product identifier\n3M\u2122 Super 77\u2122 Adhesive, Bulk       \n\nProduct Identification Numbers\n62-4458-7535-4, 62-4458-8530-4, 62-4458-9530-3\n\n1.2. Recommended use and restri
# ...

# %%
content = tika_pdf['content'].split(' ')

# %%
cleaned_content = []
for word in content:
    if word.lower() not in stopwords:
# Out:
# 3638

# %%
for item in tika_pdf['content']:
    print item
# Out:
# 3
# M
# ™
#
# S
# u
# p
# e
# r
#
# 7
# 7
# ™
#
# A
# d
# h
# e
# s
# i
# v
# e
# ,
#
# B
# u
# l
# k
#
#
#
#
# 0
# 5
# /
# 1
# 1
# /
# 1
# 5
#
#
#
#
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
#
#
#
#
# P
# a
# g
# e
#
#
# 1
#
#
# o
# f
#
#
#
#
# 1
# 2
#
#
#
#
# S
# a
# f
# e
# t
# y
#
# D
# a
# t
# a
#
# S
# h
# e
# e
# t
#
#
#
#
# C
# o
# p
# y
# r
# i
# g
# h
# t
# ,
# 2
# 0
# 1
# 5
# ,
# 3
# M
#
# C
# o
# m
# p
# a
# n
# y
# .
#
#
# A
# l
# l
#
# r
# i
# g
# h
# t
# s
#
# r
# e
# s
# e
# r
# v
# e
# d
# .
#
# C
# o
# p
# y
# i
# n
# g
#
# a
# n
# d
# /
# o
# r
#
# d
# o
# w
# n
# l
# o
# a
# d
# i
# n
# g
#
# o
# f
#
# t
# h
# i
# s
#
# i
# n
# f
# o
# r
# m
# a
# t
# ...

# %%
filename = '../SDS_3M_Adhesive.json'
filename2 = '../SDS_3M_Adhesive.pdf'

# %%
with open (filename) as json_data:
    txt = json.load(json_data)
    print txt
# Out:
# {u'formImage': {u'Pages': [{u'VLines': [], u'Fills': [{u'y': 0, u'x': 0, u'clr': 1, u'w': 0, u'h': 0}, {u'y': 5.383, u'x': 2.273, u'clr': 0, u'w': 33.615, u'h': 0.045}, {u'y': 5.427, u'x': 2.228, u'clr': 0, u'w': 0.045, u'h': 0.653}, {u'y': 6.08, u'x': 2.273, u'clr': 0, u'w': 33.615, u'h': 0.045}, {u'y': 5.427, u'x': 35.887, u'clr': 0, u'w': 0.045, u'h': 0.653}, {u'y': 49.587, u'x': 2.25, u'clr': 0, u'w': 31.267, u'h': 0.045}, {u'h': 1.005, u'oc': u'#dfdfdf', u'w': 31.41, u'y': 18.057, u'x': 2.273, u'clr': -1}, {u'h': 1.005, u'oc': u'#dfdfdf', u'w': 30.915, u'y': 18.057, u'x': 2.52, u'clr': -1}, {u'y': 18.013, u'x': 2.273, u'clr': 0, u'w': 31.41, u'h': 0.045}, {u'y': 18.057, u'x': 2.228, u'clr': 0, u'w': 0.045, u'h': 1.005}, {u'y': 19.063, u'x': 2.273, u'clr': 0, u'w': 31.41, u'h': 0.045}, {u'y': 18.057, u'x': 33.682, u'clr': 0, u'w': 0.045, u'h': 1.005}, {u'h': 1.005, u'oc': u'#dfdfdf', u'w': 31.365, u'y': 34.167, u'x': 2.273, u'clr': -1}, {u'h': 1.005, u'oc': u'#dfdfdf', u'w': 30.8
# ...

# %%
config = json.loads(open(filename).read())

# %%
config
# Out:
# {u'formImage': {u'Agency': u'',
#   u'Id': {u'AgencyId': u'',
#    u'MC': False,
#    u'Max': 1,
#    u'Name': u'',
#    u'Parent': u''},
#   u'Pages': [{u'Boxsets': [],
#     u'Fields': [],
#     u'Fills': [{u'clr': 1, u'h': 0, u'w': 0, u'x': 0, u'y': 0},
#      {u'clr': 0, u'h': 0.045, u'w': 33.615, u'x': 2.273, u'y': 5.383},
#      {u'clr': 0, u'h': 0.653, u'w': 0.045, u'x': 2.228, u'y': 5.427},
#      {u'clr': 0, u'h': 0.045, u'w': 33.615, u'x': 2.273, u'y': 6.08},
#      {u'clr': 0, u'h': 0.653, u'w': 0.045, u'x': 35.887, u'y': 5.427},
#      {u'clr': 0, u'h': 0.045, u'w': 31.267, u'x': 2.25, u'y': 49.587},
#      {u'clr': -1,
#       u'h': 1.005,
#       u'oc': u'#dfdfdf',
#       u'w': 31.41,
#       u'x': 2.273,
#       u'y': 18.057},
#      {u'clr': -1,
#       u'h': 1.005,
#       u'oc': u'#dfdfdf',
#       u'w': 30.915,
#       u'x': 2.52,
#       u'y': 18.057},
#      {u'clr': 0, u'h': 0.045, u'w': 31.41, u'x': 2.273, u'y': 18.013},
# ...
